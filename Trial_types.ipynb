# %%
from processing_pipeline import *
from model.model import *

# %%
df = load_processed_data()
# Out:
# Processed Data loaded

# %%
df.head().T
# Out:
#                                0                1                2  \
# session                        0                0                0
# mouse_name                  Cori             Cori             Cori
# trial_type                     B                A                C
# contrast_right                 0              0.5              0.5
# contrast_left                  1                0                1
# stim_loc                       1               -1                2
# winning_stim       {'left': 1.0}  {'right': -1.0}  {'right': -1.0}
# mouse_resp                     1               -1                1
# ideal_resp                     1               -1               -1
# prev_acc                     NaN                1                1
# pres_acc                       1                1                0
# contrast_diff                  1             -0.5              0.5
# abs_contrast_diff              1              0.5              0.5
# pres_difficulty                0              0.5              0.5
# prev_difficulty              NaN                0              0.5
# gocue_onset              1.02722         0.874414         0.825213
# resp_time                 1.1502           1.3995         0.949291
# latency                 0.122987         0.525089         0.124078
# feedback_onset           1.18682          1.43762         0.986016
# feedback_type                  1                1                1
# prev_feedback                NaN                1                1
#
#                                 3                4
# session                         0                0
# mouse_name                   Cori             Cori
# trial_type                      E                C
# contrast_right                  0                1
# contrast_left                   0              0.5
# stim_loc                       -1                2
# winning_stim       {'no-go': 0.0}  {'right': -1.0}
# mouse_resp                      0                1
# ideal_resp                      0               -1
# prev_acc                        0                1
# pres_acc                        1                0
# contrast_diff                   0             -0.5
# abs_contrast_diff               0              0.5
# pres_difficulty                 1              0.5
# prev_difficulty               0.5                1
# gocue_onset              0.761612          0.66201
# resp_time                  2.2668         0.816776
# latency                   1.50519         0.154765
# feedback_onset            2.29644         0.827613
# feedback_type                   1               -1
# prev_feedback                   1                1

# %%
df = df[df['trial_type'] != 'E']

# %%
np.unique(df['trial_type'])
# Out:
# array(['A', 'B', 'C'], dtype=object)
